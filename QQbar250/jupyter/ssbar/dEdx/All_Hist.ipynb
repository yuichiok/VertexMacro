# %%
import math
import numpy as np
from ROOT import gROOT, gDirectory, gPad, gSystem, gStyle
from ROOT import TCanvas, TFile, TProfile, TNtuple, TF1, TH1F, TH2F, THStack, TLegend, TGraphErrors, TMultiGraph, TText, TLatex
from ROOT import TGaxis, TCut
from ROOT import kWhite, kBlack, kGray, kRed, kGreen, kBlue, kYellow, kMagenta, kCyan, kOrange, kSpring, kTeal, kAzure, kViolet, kPink
# %jsroot on
# Out:
# Welcome to JupyROOT 6.18/00

# %%
gStyle.SetOptFit(0)
gStyle.SetOptStat(0)  
gStyle.SetOptTitle(1)
gStyle.SetTitleBorderSize(0)
gStyle.SetTitleStyle(0)
gStyle.SetMarkerSize(1)
gStyle.SetTitleX(0.2)
gStyle.SetTitleY(0.9)
gStyle.SetPadLeftMargin(0.2)

gStyle.SetTitleAlign(2)

# %%
file1 = TFile.Open("/home/ilc/yokugawa/macros/QQbar250/analysis/AFBhq2021/analysis/dEdx/rootfiles/dEdx_out.root")

# %%
def GetKeyNames( self, dir = "" ):
        self.cd(dir)
        return [key.GetName() for key in gDirectory.GetListOfKeys()]

# %%
TFile.GetKeyNames = GetKeyNames
keyList = file1.GetKeyNames()

# %%
Lobj = []
for iobj in keyList:
    print(iobj + "\n")    
    #     Lobj.append(file1.Get(iobj))
# Out:
# pion
#
# kaon
#
# proton
#
# electron
#
# muon
#
# c_dEdx
#
# n_kaon_jet
#
# pion_cos
#
# kaon_cos
#
# proton_cos
#
# electron_cos
#
# muon_cos
#
# pid_pion
#
# pid_kaon
#
# pid_proton
#
# pid_electron
#
# pid_muon
#
# c_dEdx_pid
#
# n_kaon_vtx
#
# p_kaon
#
# p_proton
#
# p_pion
#
# p_electron
#
# p_muon
#
# p_others
#
# costheta_kaon
#
# costheta_proton
#
# costheta_pion
#
# costheta_electron
#
# costheta_muon
#
# costheta_others
#
# p_kaon_method1
#
# p_proton_method1
#
# p_pion_method1
#
# p_electron_method1
#
# p_muon_method1
#
# p_others_method1
#
# p_kaon_method2
#
# p_proton_method2
#
# p_pion_method2
#
# p_electron_method2
#
# p_muon_method2
#
# p_others_method2
#
# costheta_kaon_method1
#
# costheta_proton_method1
#
# costheta_pion_method1
#
# costheta_electron_method1
#
# costheta_muon_method1
#
# costheta_others_method1
#
# costheta_kaon_method2
#
# costheta_proton_method2
#
# costheta_pion_method2
#
# costheta_electron_method2
#
# costheta_muon_method2
#
# costheta_others_method2
#
# p_costheta_kaon_method1
#
# p_costheta_proton_method1
#
# p_costheta_pion_method1
#
# p_costheta_electron_method1
#
# p_costheta_muon_method1
#
# p_costheta_others_method1
#
# p_costheta_kaon_method2
#
# p_costheta_proton_method2
#
# p_costheta_pion_method2
#
# p_costheta_electron_method2
#
# p_costheta_muon_method2
#
# p_costheta_others_method2
#
# likelihood_kaon_method1
#
# likelihood_proton_method1
#
# likelihood_pion_method1
#
# likelihood_electron_method1
#
# likelihood_muon_method1
#
# likelihood_others_method1
#
# likelihood_kaon_method2
#
# likelihood_proton_method2
#
# likelihood_pion_method2
#
# likelihood_electron_method2
#
# likelihood_muon_method2
#
# likelihood_others_method2
#
# k_prob_kaon_method1
#
# k_prob_proton_method1
#
# k_prob_pion_method1
#
# k_prob_electron_method1
#
# k_prob_muon_method1
#
# k_prob_others_method1
#
# k_prob_kaon_method2
#
# k_prob_proton_method2
#
# k_prob_pion_method2
#
# k_prob_electron_method2
#
# k_prob_muon_method2
#
# k_prob_others_method2
#
# pi_prob_kaon_method1
#
# pi_prob_proton_method1
#
# pi_prob_pion_method1
#
# pi_prob_electron_method1
#
# pi_prob_muon_method1
#
# pi_prob_others_method1
#
# pi_prob_kaon_method2
#
# pi_prob_proton_method2
#
# pi_prob_pion_method2
#
# pi_prob_electron_method2
#
# pi_prob_muon_method2
#
# pi_prob_others_method2
#
# k_pi_prob_kaon_method1
#
# k_pi_prob_proton_method1
#
# k_pi_prob_pion_method1
#
# k_pi_prob_electron_method1
#
# k_pi_prob_muon_method1
#
# k_pi_prob_others_method1
#
# k_pi_prob_kaon_method2
#
# k_pi_prob_proton_method2
#
# k_pi_prob_pion_method2
#
# k_pi_prob_electron_method2
#
# k_pi_prob_muon_method2
#
# k_pi_prob_others_method2
#
# kdEdx_dist_kaon
#
# kdEdx_dist_proton
#
# kdEdx_dist_pion
#
# kdEdx_dist_electron
#
# kdEdx_dist_muon
#
# kdEdx_dist_others
#
# p_kdEdx_dist_kaon
#
# p_kdEdx_dist_proton
#
# p_kdEdx_dist_pion
#
# p_kdEdx_dist_electron
#
# p_kdEdx_dist_muon
#
# p_kdEdx_dist_others
#
# costheta_kdEdx_dist_kaon
#
# costheta_kdEdx_dist_proton
#
# costheta_kdEdx_dist_pion
#
# costheta_kdEdx_dist_electron
#
# costheta_kdEdx_dist_muon
#
# costheta_kdEdx_dist_others
#
# n_costheta_kaon

# %%
# Lcvs = []
# for iobj in Lobj:
#     canvas = TCanvas(iobj.GetName(),iobj.GetName(),500,500)
#     iobj.SetTitle(iobj.GetName())
#     iobj.Draw()
#     Lcvs.append(canvas)

# %%
# for icvs in Lcvs:
#     icvs.Draw()
